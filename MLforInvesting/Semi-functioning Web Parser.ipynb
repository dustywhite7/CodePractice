# %%
import pandas as pd
import os
import time
from datetime import datetime

# %%
path = "/home/dusty/CodePractice/MLforInvesting/intraQuarter"

# %%
def key_stats(gather="Total Debt/Equity (mrq)"):
    statspath = path+'/_KeyStats'
    stock_list = [x[0] for x in os.walk(statspath)]
    
    for each_dir in stock_list[1:]:
        each_file = os.listdir(each_dir)
        ticker = each_dir.split("/")[-1]
        if len(each_file) > 0:
            for file in each_file:
                date_stamp = datetime.strptime(file, '%Y%m%d%H%M%S.html')
                unix_time = time.mktime(date_stamp.timetuple())
                
                full_file_path = each_dir+'/'+file
                
                print(full_file_path)
                source = open(full_file_path,'r').read()
                
                #print(source)
                
                value = source.split(gather+':</td><td class="yfnc_tabledata1">')[-1].split('</td>')[0]
                
                print(ticker+":", value)
                
            #time.sleep(15)
                

key_stats()
# Out:
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/wyn/20081202041306.html
# wyn: 1.016
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/wyn/20130425054418.html
# wyn: 236.41
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/wyn/20090214101913.html
# wyn: <html><head>
#
#
# <!-- Start Wayback Rewrite JS Include -->
# <script type="text/javascript" src="/static/js/jwplayer/jwplayer.js" ></script>
# <script type="text/javascript" src="/static/js/video-embed-rewriter.js"></script>
# <script type="text/javascript">
# function initYTVideo(id)
# {
# 	_wmVideos_.init("/web/", id);
# }
# </script>
# <!-- End Wayback Rewrite JS Include -->
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8"><title>WYN: Key Statistics for WYNDHAM WORLDWIDE - Yahoo! Finance</title><link rel="stylesheet" type="text/css" href="/web/20090214101913cs_/http://us.js2.yimg.com/us.yimg.com/i/us/fi/yfs/css/yf_streaming_1.4.css"><link rel="stylesheet" type="text/css" href="/web/20090214101913cs_/http://us.js2.yimg.com/us.js.yimg.com/i/us/fi/yfss/css/yf_symbolsuggest_1.19.css"><link href="/web/20090214101913cs_/http://us.js2.yimg.com/us.js.yimg.com/i/us/fi/navbar/css/gnav_200710261422.css" type="text/css" rel="stylesheet"><script type="text/javascript" src="/web/20090214101913js_/http://us.js2.yimg.com/us.js.yimg.com/i/us/fi/scripts/gnavb_200702051500.js"></script><!--[if lte IE 7]>
#         <link href="/web/20090214101913/http://us.js2.yimg.com/us.js.yimg.com/i/us/fi/navbar/css/ie6_200701252030.css" type="text/css" rel="stylesheet" media="all"/>
#         <script type="text/javascript" src="/web/20090214101913/http://us.js2.yimg.com/us.js.yimg.com/i/us/fi/navbar/scripts/pseudohover_200701262100.js"></script>
#         <![endif]--><script type="text/javascript" src="/web/20090214101913js_/http://us.js2.yimg.com/us.yimg.com/i/us/fi/03rd/yg_csstare_nobgcolor.js"></script><link rel="stylesheet" href="/web/20090214101913cs_/http://us.js2.yimg.com/us.js.yimg.com/i/us/fi/03rd/yfnc_200712171510.css" type="text/css" media="screen"><style media="screen">
# #screen,#masthead{text-align:center;margin:0;width:752px;}
# #screen.xpand,#masthead.xpand{width:100%;}
# #screen.xpand #yfncsubtit{width:100%;}
# #masthead{padding-bottom:12px;}
# #leftcol,#rightcol{margin:0;}
# #leftcol{width:155px;float:left;}
# #rightcol{width:585px;}
# #content{width:752px;}
# #footer {clear:both;}
#
# /*/*/
# body{text-align:center;}
# #screen{text-align:left;min-width:700px;width:62.5em;width:expression(
# document.all.footer ? (document.all.footer.offsetWidth>1000) ? '980'+'px' : document.all.footer.offsetWidth :'62.5'+'em') ;margin:auto;border:1px solid #FFF;}
# #screen.xpand{width:100%; text-align:center}
# #portfolio{margin:10px auto;}
# #hdrads{margin:10px auto 0 auto;}
# #masthead,#leftcol,#rightcol{margin:0;}
# #masthead{width:100%;}
# #leftcol{float:left;width:18%;}
# #rightcol{float:right;width:80%;}
# #content{width:100%;}
# #footer{clear:both;text-align:center;padding:10px
# 0;width:60em;margin:auto;border:0px solid #FFF;} #leftNavTable,#yfncmh,#yfncmkttme,#yfncduplgnwrn,#yfncpsnlbar,#yfnctitbar,#y
# fncsubtit,#yfncbrobtn,#yfncsumtab,
# .yfnc_systitlelinea1,.yfnc_systitlelineb1,.yfnc_modtitlew1{
#   width:100%;}
# #yfncmh{width:100%;}
# .yfncsumdatagrid{background:#DCDCDC;width:100%;}
# .yfnc_modtitlew2{width:49%;}
# /**/
#
# .yfncnhl{color:#666;margin-bottom:10px;}
# .yfncnhl .yfncnhlbl{color:#000;width:1.6em;text-align:center;}
# .yfncnhl .yfncnhltt{color:#000;width:50px;padding-top:2px;}
# .yfncnhltt {
#     position: relative;
# }
# .yfncnhltt a {
#     position: relative;
# 	display: block; /* opera */
# 	width: 42px;
# 	height: 31px;
# }
# .yfncnhltt img {
# 	border: 0;
# }
# .yfncnhltt img.video_play {
#     position: absolute;
#     bottom: 2px;
#     left: 2px;
#     width: 13px;
#     height: 14px;
# }
# </style><style media="print">
# #leftcol{display:none;}
# #rightcol{display:block;}
# </style><meta name="keywords" content="Beta,EPS,P/E,PEG,Price/book. EBITDA,Profit margin,Return on Equity,financial statistics,key statistics,market cap,measurement,operating Margin,short ratio,valuation"><meta name="description" content="Find out all the key statistics for WYNDHAM WORLDWIDE (WYN), including valuation measures, fiscal year financial statistics, trading record, share statistics and more."><script type="text/javascript"><!--
#       var yfid    = document;
#       var yfiagt  = navigator.userAgent.toLowerCase();
#       var yfidom  = yfid.getElementById;
#       var yfiie   = yfid.all;
#       var yfimac  = (yfiagt.indexOf('mac')!=-1);
#       var yfimie  = (yfimac&&yfiie);
#       var yfiie5  = (yfiie&&yfidom&&!yfimie&&!Array.prototype.pop);
#       var yfiie55 = (yfiie&&yfidom&&!yfimie&&!yfiie5);
#       var yfiie6  = (yfiie55&&yfid.compatMode);
#       var yfisaf  = ((yfiagt.indexOf('safari')>-1)?1:0);
#       var yfimoz  = ((yfiagt.indexOf('gecko')>-1&&!yfisaf)?1:0);
#       var yfiopr  = ((yfiagt.indexOf('opera')>-1&&!yfisaf)?1:0);
#     //--></script><script type="text/javascript" src="/web/20090214101913js_/http://us.js2.yimg.com/us.js.yimg.com/lib/fi/utilities_0.1.2.js"></script><script type="text/javascript"><!--
#           if(yfidom&&!yfimie){yfid.onkeydown=yfi_kd;}
#         //--></script></head><body>
# <!-- BEGIN WAYBACK TOOLBAR INSERT -->
#
# <script type="text/javascript" src="/static/js/disclaim-element.js" ></script>
# <script type="text/javascript" src="/static/js/graph-calc.js" ></script>
# <script type="text/javascript" src="/static/jflot/jquery.min.js" ></script>
# <script type="text/javascript">
# //<![CDATA[
# var firstDate = 820454400000;
# var lastDate = 1388534399999;
# var wbPrefix = "/web/";
# var wbCurrentUrl = "http:\/\/finance.yahoo.com\/q\/ks?s=WYN";
#
# var curYear = -1;
# var curMonth = -1;
# var yearCount = 18;
# var firstYear = 1996;
# var imgWidth = 450;
# var yearImgWidth = 25;
# var monthImgWidth = 2;
# var trackerVal = "none";
# var displayDay = "14";
# var displayMonth = "Feb";
# var displayYear = "2009";
# var prettyMonths = ["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"];
#
# function showTrackers(val) {
# 	if(val == trackerVal) {
# 		return;
# 	}
# 	if(val == "inline") {
# 		document.getElementById("displayYearEl").style.color = "#ec008c";
# 		document.getElementById("displayMonthEl").style.color = "#ec008c";
# 		document.getElementById("displayDayEl").style.color = "#ec008c";
# 	} else {
# 		document.getElementById("displayYearEl").innerHTML = displayYear;
# 		document.getElementById("displayYearEl").style.color = "#ff0";
# 		document.getElementById("displayMonthEl").innerHTML = displayMonth;
# 		document.getElementById("displayMonthEl").style.color = "#ff0";
# 		document.getElementById("displayDayEl").innerHTML = displayDay;
# 		document.getElementById("displayDayEl").style.color = "#ff0";
# 	}
#    document.getElementById("wbMouseTrackYearImg").style.display = val;
#    document.getElementById("wbMouseTrackMonthImg").style.display = val;
#    trackerVal = val;
# }
# function getElementX2(obj) {
# 	var thing = jQuery(obj);
# 	if((thing == undefined)
# 			|| (typeof thing == "undefined")
# 			|| (typeof thing.offset == "undefined")) {
# 		return getElementX(obj);
# 	}
# 	return Math.round(thing.offset().left);
# }
# function trackMouseMove(event,element) {
#
#    var eventX = getEventX(event);
#    var elementX = getElementX2(element);
#    var xOff = eventX - elementX;
# 	if(xOff < 0) {
# 		xOff = 0;
# 	} else if(xOff > imgWidth) {
# 		xOff = imgWidth;
# 	}
#    var monthOff = xOff % yearImgWidth;
#
#    var year = Math.floor(xOff / yearImgWidth);
# 	var yearStart = year * yearImgWidth;
#    var monthOfYear = Math.floor(monthOff / monthImgWidth);
#    if(monthOfYear > 11) {
#        monthOfYear = 11;
#    }
#    // 1 extra border pixel at the left edge of the year:
#    var month = (year * 12) + monthOfYear;
#    var day = 1;
# 	if(monthOff % 2 == 1) {
# 		day = 15;
# 	}
# 	var dateString =
# 		zeroPad(year + firstYear) +
# 		zeroPad(monthOfYear+1,2) +
# 		zeroPad(day,2) + "000000";
#
# 	var monthString = prettyMonths[monthOfYear];
# 	document.getElementById("displayYearEl").innerHTML = year + 1996;
# 	document.getElementById("displayMonthEl").innerHTML = monthString;
# 	// looks too jarring when it changes..
# 	//document.getElementById("displayDayEl").innerHTML = zeroPad(day,2);
#
# 	var url = wbPrefix + dateString + '/' +  wbCurrentUrl;
# 	document.getElementById('wm-graph-anchor').href = url;
#
#    //document.getElementById("wmtbURL").value="evX("+eventX+") elX("+elementX+") xO("+xOff+") y("+year+") m("+month+") monthOff("+monthOff+") DS("+dateString+") Moy("+monthOfYear+") ms("+monthString+")";
#    if(curYear != year) {
#        var yrOff = year * yearImgWidth;
#        document.getElementById("wbMouseTrackYearImg").style.left = yrOff + "px";
#        curYear = year;
#    }
#    if(curMonth != month) {
#        var mtOff = year + (month * monthImgWidth) + 1;
#        document.getElementById("wbMouseTrackMonthImg").style.left = mtOff + "px";
#        curMonth = month;
#    }
# }
# //]]>
# </script>
#
# <style type="text/css">body{margin-top:0!important;padding-top:0!important;min-width:800px!important;}#wm-ipp a:hover{text-decoration:underline!important;}</style>
# <div id="wm-ipp" style="display:none; position:relative;padding:0 5px;min-height:70px;min-width:800px; z-index:9000;">
# <div id="wm-ipp-inside" style="position:fixed;padding:0!important;margin:0!important;width:97%;min-width:780px;border:5px solid #000;border-top:none;background-image:url(/static/images/toolbar/wm_tb_bk_trns.png);text-align:center;-moz-box-shadow:1px 1px 3px #333;-webkit-box-shadow:1px 1px 3px #333;box-shadow:1px 1px 3px #333;font-size:11px!important;font-family:'Lucida Grande','Arial',sans-serif!important;">
#    <table style="border-collapse:collapse;margin:0;padding:0;width:100%;"><tbody><tr>
#    <td style="padding:10px;vertical-align:top;min-width:110px;">
#    <a href="/web/" title="Wayback Machine home page" style="background-color:transparent;border:none;"><img src="/static/images/toolbar/wayback-toolbar-logo.png" alt="Wayback Machine" width="110" height="39" border="0"/></a>
#
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/wyn/20080222152749.html
# wyn: 1.018
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/wyn/20070618034221.html
# wyn: 0.917
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/wyn/20120225182951.html
# wyn: 180.33
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/shld/20120106223359.html
# shld: 58.99
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/shld/20121015113738.html
# shld: 73.40
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/shld/20081219235448.html
# shld: 0.48
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/shld/20070825002730.html
# shld: 0.295
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/shld/20070328152606.html
# shld: 0.28
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/shld/20130422072211.html
# shld: 98.36
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/shld/20130314192330.html
# shld: 98.36
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/shld/20070630050754.html
# shld: 0.295
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/shld/20080124090523.html
# shld: 0.408
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/shld/20130514042947.html
# shld: 98.36
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/shld/20111229083840.html
# shld: 58.99
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/shld/20060813145508.html
# shld: 0.339
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/shld/20071213012955.html
# shld: 0.408
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/shld/20070527153817.html
# shld: 0.307
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/shld/20110906054223.html
# shld: 45.88
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/shld/20070427091252.html
# shld: 0.307
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/shld/20120618181927.html
# shld: 70.53
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/agn/20080123230653.html
# agn: 0.449
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/agn/20041102140949.html
# agn: 0.637
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/agn/20060621092901.html
# agn: 0.47
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/agn/20050829124247.html
# agn: 0.51
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/agn/20040619144929.html
# agn: 0.695
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/agn/20070406222810.html
# agn: 0.544
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/agn/20070220163000.html
# agn: 0.544
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/agn/20080517082431.html
# agn: 0.429
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/agn/20050404232033.html
# agn: 0.522
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/agn/20130422024952.html
# agn: 26.63
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/agn/20130512050818.html
# agn: 40.37
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/agn/20040810023338.html
# agn: 0.637
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/agn/20050310014057.html
# agn: 0.522
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/agn/20031117224603.html
# agn: 0.739
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/agn/20120822225841.html
# agn: 28.52
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/agn/20080216184449.html
# agn: 0.436
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/agn/20120811080633.html
# agn: 28.52
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/intc/20040810130618.html
# intc: 0.029
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/intc/20120303233418.html
# intc: 16.15
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/intc/20130130101806.html
# intc: 26.26
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/intc/20070516075853.html
# intc: 0.053
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/intc/20070718005338.html
# intc: 0.053
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/intc/20070616131753.html
# intc: 0.053
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/intc/20081027191001.html
# intc: 0.061
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/intc/20120620095527.html
# intc: 16.09
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/intc/20121104082959.html
# intc: 14.52
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/intc/20070329103613.html
# intc: 0.055
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/intc/20120701230941.html
# intc: 16.09
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/intc/20081204110021.html
# intc: 0.061
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/intc/20070309023748.html
# intc: 0.055
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/intc/20070310224133.html
# intc: 0.055
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/intc/20031207160220.html
# intc: 0.033
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/intc/20070514101113.html
# intc: 0.053
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/intc/20081204234858.html
# intc: 0.061
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/intc/20090414132648.html
# intc: N/A
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/intc/20080123065214.html
# intc: 0.05
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/intc/20110902041619.html
# intc: 4.82
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/intc/20051219201544.html
# intc: 0.019
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/intc/20111105042801.html
# intc: 15.49
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/intc/20070311133720.html
# intc: 0.055
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/intc/20080316182000.html
# intc: 0.05
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/intc/20070227211557.html
# intc: 0.055
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/intc/20080407092838.html
# intc: 0.05
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/intc/20071013160749.html
# intc: 0.052
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/intc/20120502031754.html
# intc: 15.93
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/intc/20050305101317.html
# intc: 0.023
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/intc/20120101093057.html
# intc: 15.76
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/intc/20111028081446.html
# intc: 15.49
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/intc/20041010035747.html
# intc: 0.029
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/intc/20130422015420.html
# intc: 25.85
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/intc/20040621113342.html
# intc: 0.032
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/intc/20040213062941.html
# intc: 0.031
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/intc/20031103144511.html
# intc: 0.033
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/intc/20060224094527.html
# intc: <html>
# <head>
#
#
# <!-- Start Wayback Rewrite JS Include -->
# <script type="text/javascript" src="/static/js/jwplayer/jwplayer.js" ></script>
# <script type="text/javascript" src="/static/js/video-embed-rewriter.js"></script>
# <script type="text/javascript">
# function initYTVideo(id)
# {
# 	_wmVideos_.init("/web/", id);
# }
# </script>
# <!-- End Wayback Rewrite JS Include -->
#
# <meta http-equiv="Content-Type" content="text/html; charset=iso-8859-1">
# <title>INTC: Key Statistics for INTEL CP - Yahoo! Finance</title>
# <link href="/web/20060224094527cs_/http://us.js2.yimg.com/us.js.yimg.com/i/us/fi/navbar/css/gnavb_200602071227.css" type="text/css" rel="stylesheet">
# <script language="javascript" src="/web/20060224094527js_/http://us.js2.yimg.com/us.js.yimg.com/i/us/fi/navbar/scripts/gnavb_200602071227.js" type="text/javascript"></script><script type="text/javascript" src="/web/20060224094527js_/http://us.i1.yimg.com/us.yimg.com/i/us/fi/03rd/yg_csstare_nobgcolor.js"></script><link rel="stylesheet" href="/web/20060224094527cs_/http://us.i1.yimg.com/us.yimg.com/i/us/fi/03rd/yfnc2.css" type="text/css" media="screen">
# <style media="screen">
# #screen,#masthead{text-align:center;margin:0;width:752px;}
# #screen.xpand,#masthead.xpand{width:100%;}
# #screen.xpand #yfncsubtit{width:100%;}
# #masthead{padding-bottom:12px;}
# #leftcol,#rightcol{margin:0;}
# #leftcol{width:155px;float:left;}
# #rightcol{width:585px;}
# #content{width:752px;}
# #footer {clear:both;}
#
# /*/*/
# body{text-align:center;}
# #screen{text-align:left;min-width:700px;width:62.5em;width:expression(
# document.all.footer ? (document.all.footer.offsetWidth>1000) ? '980'+'px' : document.all.footer.offsetWidth :'62.5'+'em') ;margin:auto;border:1px solid #FFF;}
# #screen.xpand{width:100%; text-align:center}
# #portfolio{margin:10px auto;}
# #hdrads{margin:10px auto 0 auto;}
# #masthead,#leftcol,#rightcol{margin:0;}
# #masthead{width:100%;}
# #leftcol{float:left;width:18%;}
# #rightcol{float:right;width:80%;}
# #content{width:100%;}
# #footer{clear:both;text-align:center;padding:10px
# 0;width:60em;margin:auto;border:0px solid #FFF;} #leftNavTable,#yfncmh,#yfncmkttme,#yfncduplgnwrn,#yfncpsnlbar,#yfnctitbar,#y
# fncsubtit,#yfncbrobtn,#yfncsumtab,
# .yfnc_systitlelinea1,.yfnc_systitlelineb1,.yfnc_modtitlew1{
#   width:100%;}
# #yfncmh{width:100%;}
# .yfncsumdatagrid{background:#DCDCDC;width:100%;}
# .yfnc_modtitlew2{width:49%;}
# /**/
#
# .yfncnhl{color:#666;margin-bottom:10px;}
# .yfncnhl .yfncnhlbl{color:#000;width:1.6em;text-align:center;}
# </style>
# <style media="print">
# #leftcol{display:none;}
# #rightcol{display:block;}
# </style>
# <meta name="keywords" content="Beta,EPS,P/E,PEG,Price/book. EBITDA,Profit margin,Return on Equity,financial statistics,key statistics,market cap,measurement,operating Margin,short ratio,valuation">
# <meta name="description" content="Find out all the key statistics for INTEL CP (INTC), including valuation measures, fiscal year financial statistics, trading record, share statistics and more.">
# <script type="text/javascript"><!--
#       var yfid    = document;
#       var yfiagt  = navigator.userAgent.toLowerCase();
#       var yfidom  = yfid.getElementById;
#       var yfiie   = yfid.all;
#       var yfimac  = (yfiagt.indexOf('mac')!=-1);
#       var yfimie  = (yfimac&&yfiie);
#       var yfiie5  = (yfiie&&yfidom&&!yfimie&&!Array.prototype.pop);
#       var yfiie55 = (yfiie&&yfidom&&!yfimie&&!yfiie5);
#       var yfiie6  = (yfiie55&&yfid.compatMode);
#       var yfisaf  = ((yfiagt.indexOf('safari')>-1)?1:0);
#       var yfimoz  = ((yfiagt.indexOf('gecko')>-1&&!yfisaf)?1:0);
#       var yfiopr  = ((yfiagt.indexOf('opera')>-1&&!yfisaf)?1:0);
#     //--></script><script type="text/javascript" src="/web/20060224094527js_/http://us.js1.yimg.com/us.js.yimg.com/lib/fi/utilities_0.1.1.js"></script><script type="text/javascript"><!--
#           if(yfidom&&!yfimie){yfid.onkeydown=yfi_kd;}
#         //--></script>
# </head>
# <body>
# <!-- BEGIN WAYBACK TOOLBAR INSERT -->
#
# <script type="text/javascript" src="/static/js/disclaim-element.js" ></script>
# <script type="text/javascript" src="/static/js/graph-calc.js" ></script>
# <script type="text/javascript" src="/static/jflot/jquery.min.js" ></script>
# <script type="text/javascript">
# //<![CDATA[
# var firstDate = 820454400000;
# var lastDate = 1388534399999;
# var wbPrefix = "/web/";
# var wbCurrentUrl = "http:\/\/finance.yahoo.com\/q\/ks?s=INTC";
#
# var curYear = -1;
# var curMonth = -1;
# var yearCount = 18;
# var firstYear = 1996;
# var imgWidth = 450;
# var yearImgWidth = 25;
# var monthImgWidth = 2;
# var trackerVal = "none";
# var displayDay = "24";
# var displayMonth = "Feb";
# var displayYear = "2006";
# var prettyMonths = ["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"];
#
# function showTrackers(val) {
# 	if(val == trackerVal) {
# 		return;
# 	}
# 	if(val == "inline") {
# 		document.getElementById("displayYearEl").style.color = "#ec008c";
# 		document.getElementById("displayMonthEl").style.color = "#ec008c";
# 		document.getElementById("displayDayEl").style.color = "#ec008c";
# 	} else {
# 		document.getElementById("displayYearEl").innerHTML = displayYear;
# 		document.getElementById("displayYearEl").style.color = "#ff0";
# 		document.getElementById("displayMonthEl").innerHTML = displayMonth;
# 		document.getElementById("displayMonthEl").style.color = "#ff0";
# 		document.getElementById("displayDayEl").innerHTML = displayDay;
# 		document.getElementById("displayDayEl").style.color = "#ff0";
# 	}
#    document.getElementById("wbMouseTrackYearImg").style.display = val;
#    document.getElementById("wbMouseTrackMonthImg").style.display = val;
#    trackerVal = val;
# }
# function getElementX2(obj) {
# 	var thing = jQuery(obj);
# 	if((thing == undefined)
# 			|| (typeof thing == "undefined")
# 			|| (typeof thing.offset == "undefined")) {
# 		return getElementX(obj);
# 	}
# 	return Math.round(thing.offset().left);
# }
# function trackMouseMove(event,element) {
#
#    var eventX = getEventX(event);
#    var elementX = getElementX2(element);
#    var xOff = eventX - elementX;
# 	if(xOff < 0) {
# 		xOff = 0;
# 	} else if(xOff > imgWidth) {
# 		xOff = imgWidth;
# 	}
#    var monthOff = xOff % yearImgWidth;
#
#    var year = Math.floor(xOff / yearImgWidth);
# 	var yearStart = year * yearImgWidth;
#    var monthOfYear = Math.floor(monthOff / monthImgWidth);
#    if(monthOfYear > 11) {
#        monthOfYear = 11;
#    }
#    // 1 extra border pixel at the left edge of the year:
#    var month = (year * 12) + monthOfYear;
#    var day = 1;
# 	if(monthOff % 2 == 1) {
# 		day = 15;
# 	}
# 	var dateString =
# 		zeroPad(year + firstYear) +
# 		zeroPad(monthOfYear+1,2) +
# 		zeroPad(day,2) + "000000";
#
# 	var monthString = prettyMonths[monthOfYear];
# 	document.getElementById("displayYearEl").innerHTML = year + 1996;
# 	document.getElementById("displayMonthEl").innerHTML = monthString;
# 	// looks too jarring when it changes..
# 	//document.getElementById("displayDayEl").innerHTML = zeroPad(day,2);
#
# 	var url = wbPrefix + dateString + '/' +  wbCurrentUrl;
# 	document.getElementById('wm-graph-anchor').href = url;
#
#    //document.getElementById("wmtbURL").value="evX("+eventX+") elX("+elementX+") xO("+xOff+") y("+year+") m("+month+") monthOff("+monthOff+") DS("+dateString+") Moy("+monthOfYear+") ms("+monthString+")";
#    if(curYear != year) {
#        var yrOff = year * yearImgWidth;
#        document.getElementById("wbMouseTrackYearImg").style.left = yrOff + "px";
#        curYear = year;
#    }
#    if(curMonth != month) {
#        var mtOff = year + (month * monthImgWidth) + 1;
#        document.getElementById("wbMouseTrackMonthImg").style.left = mtOff + "px";
#        curMonth = month;
#    }
# }
# //]]>
# </script>
#
# <style type="text/css">body{margin-top:0!important;padding-top:0!important;min-width:800px!important;}#wm-ipp a:hover{text-decoration:underline!important;}</style>
# <div id="wm-ipp" style="display:none; position:relative;padding:0 5px;min-height:70px;min-width:800px; z-index:9000;">
# <div id="wm-ipp-inside" style="position:fixed;padding:0!important;margin:0!important;width:97%;min-width:780px;border:5px solid #000;border-top:none;background-image:url(/static/images/toolbar/wm_tb_bk_trns.png);text-align:center;-moz-box-shadow:1px 1px 3px #333;-webkit-box-shadow:1px 1px 3px #333;box-shadow:1px 1px 3px #333;font-size:11px!important;font-family:'Lucida Grande','Arial',sans-serif!important;">
#    <table style="border-collapse:collapse;margin:0;padding:0;width:100%;"><tbody><tr>
#    <td style="padding:10px;vertical-align:top;min-width:110px;">
#    <a href="/web/" title="Wayback Machine home page" style="background-color:transparent;border:none;"><img src="/static/images/toolbar/wayback-toolbar-logo.png" alt="Wayback Machine" width="110" height="39" border="0"/></a>
#
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/intc/20070408113621.html
# intc: 0.055
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/intc/20111229050419.html
# intc: 15.76
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/intc/20070409132328.html
# intc: 0.055
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/intc/20121111172228.html
# intc: 14.71
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/intc/20070704034407.html
# intc: 0.053
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/intc/20041214013836.html
# intc: 0.029
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/intc/20070320135031.html
# intc: 0.055
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/intc/20130516161706.html
# intc: 26.08
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/intc/20120831165036.html
# intc: 14.83
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/intc/20111101180901.html
# intc: 15.49
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/intc/20120306195318.html
# intc: 16.15
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/intc/20120302065802.html
# intc: 16.15
# /home/dusty/CodePractice/MLforInvesting/intraQuarter/_KeyStats/intc/20081218214751.html
# intc: 0.061
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-da1b83449744> in <module>()
#      25
#      26
# ---> 27 key_stats()
#
# <ipython-input-14-da1b83449744> in key_stats(gather)
#      22                 print(ticker+":", value)
#      23
# ---> 24             time.sleep(15)
#      25
#      26
#
# KeyboardInterrupt:
